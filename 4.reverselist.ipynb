# %% [markdown]
# # 206.翻转链表
#
# [力扣题目链接](https://leetcode.cn/problems/reverse-linked-list/)
#
# 题意：反转一个单链表
# 示例: 输入: 1->2->3->4->5->NULL 输出: 5->4->3->2->1->NULL

# %%
class ListNode:
    def __init__(self,val=0,next=None):
        self.val = val
        self.next= next

class Solution(object):
    def reverseList(self, head):
        """
        :type head: Optional[ListNode]
        :rtype: Optional[ListNode]
        """
        prev = None #已经反转好的部分
        curr = head

        while curr: #curr最终移动到null，此时curr = False
            #存下next，不然会断路
            nxt = curr.next
            #翻转
            curr.next = prev
            #挪动prev到当前位置
            prev = curr
            #挪动curr进一步翻转
            curr = nxt
        return prev
