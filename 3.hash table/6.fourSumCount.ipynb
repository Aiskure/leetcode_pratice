# %% [markdown]
# # 454.四数相加II
#
# [力扣题目链接](https://leetcode.cn/problems/4sum-ii/)
#
# 给定四个包含整数的数组列表 A , B , C , D ,计算有多少个元组 (i, j, k, l) ，使得 A[i] + B[j] + C[k] + D[l] = 0。
#
# 为了使问题简单化，所有的 A, B, C, D 具有相同的长度 N，且 $0 ≤ N ≤ 500$ 。所有整数的范围在 $-2^{28}$ 到 $2^{28} - 1$ 之间，最终结果不会超过 $2^{31}- 1$ 。
#
# **例如:**
#
# 输入:
#
# - A = [ 1, 2]
# - B = [-2,-1]
# - C = [-1, 2]
# - D = [ 0, 2]
#
# 输出:
#
# 2
#
# **解释:**
#
# 两个元组如下:
#
# 1. (0, 0, 0, 1) -> A[0] + B[0] + C[0] + D[1] = 1 + (-2) + (-1) + 2 = 0
# 2. (1, 1, 0, 0) -> A[1] + B[1] + C[0] + D[0] = 2 + (-1) + (-1) + 0 = 0

# %% [markdown]
# **思路**
#
# 1. 首先定义 一个unordered_map，key放a和b两数之和，value 放a和b两数之和出现的次数。
# 2. 遍历大A和大B数组，统计两个数组元素之和，和出现的次数，放到map中。
# 3. 定义int变量count，用来统计 a+b+c+d = 0 出现的次数。
# 4. 再遍历大C和大D数组，找到如果 0-(c+d) 在map中出现过的话，就用count把map中key对应的value也就是出现次数统计出来。
# 5. 最后返回统计值 count 就可以了
#
# 我们可以用`defaultdict(int)`
# ```python
# # 普通字典
# d = {}
# d['a'] += 1   # 报错！KeyError: 'a' 因为 'a' 不存在
#
# # defaultdict
# d = defaultdict(int)   # 指定默认值为 0（int 的默认是 0）
# d['a'] += 1            # 不会报错！自动把 'a' 的值设为 0，然后 +1 → 1
# print(d)               # defaultdict(<class 'int'>, {'a': 1})
# print(dict(d))         # {'a': 1}
# ```
#
# 比dict.get(x,0)更快

# %%
class Solution(object):
    def fourSumCount(self, nums1, nums2, nums3, nums4):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :type nums3: List[int]
        :type nums4: List[int]
        :rtype: int
        """
        record = dict()
        for i in nums1:
            for j in nums2:
                record[i+j] = record.get(i+j,0) + 1

        x = 0
        for i in nums3:
            for j in nums4:
                if -(i + j) in record:
                    x += record[-(i+j)]
        return x


class Solution(object):
    def fourSumCount(self, nums1, nums2, nums3, nums4):
        """
        :type nums1: List[int]
        :type nums2: List[int]
        :type nums3: List[int]
        :type nums4: List[int]
        :rtype: int
        """
        tmp = defaultdict(int)
        result = 0
        for i in nums1:
            for j in nums2:
                tmp[i + j] += 1
        for i in nums3:
            for j in nums4:
                result += tmp[-i - j]
        return result

# %%
A = [1,2]
B = [-1,-2]
C = [-1,2]
D = [0,2]
record1 = dict()
for i in A:
    for j in B:
        record1[i+j] =record1.get(i+j,0)+1
record2 = dict()
for i in C:
    for j in D:
        record2[-(i+j)] =record2.get(-(i+j),0)+1

# %%
print(record1,record2)
# Out:
# {0: 2, -1: 1, 1: 1} {1: 1, -1: 1, -2: 1, -4: 1}
